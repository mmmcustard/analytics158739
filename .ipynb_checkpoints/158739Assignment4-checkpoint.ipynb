# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from typing import Union
import seaborn as sns
import datetime
import requests
from bs4 import BeautifulSoup
# Out:
# <style>.container { width:85% !important; }</style>

# %% [markdown]
# # 158739 Assignment 4 - Does having wealthy parents make you a better tennis player?
#
# #### Student name: James Evans and Hayley Wikeepa
# #### Student ID: 12211872 & 19034759
#
#
# # Introduction
#
#
#
# Does having wealth parent make you a better tennis player? There are lots of ways to analise this. We can look at if the current world top tennis players are mostly from wealth families. We can look if being from a wealthy family makes it more likely you will win when playing profesional tennis. Assuming this is true we can look if having wealthy parents is "priced in" to the betting odds when betting on tennis matches.
#
# Two things that make us wonder about tennis and wealthy parents. Firstly there are two of the top 100 woman tennis players have billionare parent. Second a tweet one of us saw wondering why so many formula one drivers fathers have hyperlinks in wikipedia (hinting that you need a rich father to become a formular 1 driver).
#
#
#
#
#
# #### Datasets used:
# - ATP (Mens profesional tennis assossiation) and WTA (Womens profesional tennis assossiation) tennis player lists
# - Tennis results from the years 2019 - 2023
# - Tennis betting odds from the years 2019 - 2023
# - List of tennis players that have wiki pages, and a boolean if there parents have wiki pages
# - chat gpt answers to the question "did this tennis player have wealthy parents?"
#
#
# #### Dataset sources:
#
# - http://www.tennis-data.co.uk/alldata.php
# - Wikipedia
# - ChatGPT
#
#
# ### Research Questions
#
# 1. Is having wealth parents a predictor of becoming a profectional tennis player?
# 2. Is having wealth parents a predictor of future sucssess as a profectional tennis player?
# 3. Is there money to be made by taking into account if a tennis player has wealth parents, when betting on a tennis mathches?
#
#
# ### Executive Summary

# %% [markdown]
# ## What do we need to achive?
#
#
# ### Ideas of what we could find out
#
# First we could see if there is a disporportinate amount of pro tennis players that have wealth parents (I am sure there will be).
#
# Would could see if there is a correlation between rich partents and tennis success when playing as a pro (look at results from pro matches).
# we could look at win % vs wealthy parents
#
# If answer is yes, wealth parents make you play better as a pro, then we can look to see if this is taken into account in the betting odds.
# For each player, we could work out how much you would have won / lost, if you had bet a constant amount on that player, over there last x number of games. We can then have a way of saying who is a profitable player and who is an unprofitable player to bet on. We can then see if this correlates with if they have rich/famous parents.
#
#
# ### Marking info
#
# - Data Acquisition -     20
#     * Diversity of sources (at least one must be dynamic – full marks for using both APIs and web scraping – penalties will be applied for re-using examples from class)
#     * Appropriate use of merging and concatenation.
#
# - Data Wrangling and EDA  -  30
# - Data Analysis -  35
# - Originality and challenge 15
#
# BONUS
# - Big Data ProcessingTechniques - 5
#
# ### Other notes from the brief
# Clearly introduce your problem domain, articulate your research questions and provide an executive summary at the beginning. Follow the provided Jupyter notebook template.
# You must document and explain the reasoning behind the coding steps you are taking and provide explanations of all your graphs and tables as is appropriate. Make sure you label all aspects of your graphs.
# The activities listed under the five stages in the workflow diagram above are a guide only. This means that operations like group-by statements as well as pivot tables could be a part of the ‘Data Wrangling’ phase as EDA, and not only a part of the data analysis phase. Finally, please run your report through an external spell checker and feel free to use ChatGPT judiciously to help you as discussed in class.

# %%
# initialise APIs

api_key = '8556d4b2f5mshddae5c2b7778158p1b7b83jsn131f0acf695b'

# initialise https://rapidapi.com/sportcontentapi/api/ultimate-tennis1 API
ultimate_tennis_headers =  {
    'X-RapidAPI-Key': api_key,
    'X-RapidAPI-Host': 'ultimate-tennis1.p.rapidapi.com'
}

# %% [markdown]
# #### Initialise functions

# %%
#Function returns true if ChatGPT things a tennis player had wealth parents (top 1% weath in there country).
#function created by Chat GPT and modified by us.

#Note/ function cost about $0.0002 each time it is run. 

API_ENDPOINT = "https://api.openai.com/v1/chat/completions"
API_KEY = "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"
MODEL_NAME = "gpt-3.5-turbo"

def determine_wealthy_parents(tennis_player_name):
    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {API_KEY}"
    }
    data = {
        "messages": [
            {"role": "system", "content": "You are a helpful assistant who only ever responds with yes or no answers. If you do not have enough information, answer no. Wealthy means the parents were probably in the top 1% of people in there country."},
            {"role": "user", "content": f"Did the tennis player {tennis_player_name}, have wealthy parents?"}
        ],
        "model": MODEL_NAME
    }
    response = requests.post(API_ENDPOINT, headers=headers, json=data)
    response_json = response.json()
    #print (response_json)
    try:
        chat_reply = response_json['choices'][0]['message']['content']
        # You can modify the condition below based on the expected response from the model
        if "yes" in chat_reply.lower():
            return True
        elif "no" in chat_reply.lower():
            return False
        else:
            return None  # Unable to determine the response
    except KeyError:
        return None  # Invalid response format

# %%
# scraping wiki to find parents. We can use this to check out results from Chat GPT

#Todo// Get this working. Currently isssue with find_next_sibling method not returning the info we want.

def parents_have_wiki(url):
    parents = []  # initialize the parents list
    last_name = None  # initialize the last name variable
    
    # Make a request to the URL and get the HTML response
    response = requests.get(url)
    html = response.content
    
    # Parse the HTML with BeautifulSoup
    soup = BeautifulSoup(html, 'html.parser')
    
    # Find the "Personal life" or "Early life" or "Personal info" section on the page
    personal_life_section = soup.find('span', {'id': 'Early_life'})
    if personal_life_section is None:
        personal_life_section = soup.find('span', {'id': 'Personal_life'})
    if personal_life_section is None:
        personal_life_section = soup.find('span', {'id': 'Personal_info'})
       
    # Look for parents in the infobox
    infobox = soup.find('table', {'class': 'infobox'})
    if infobox:
        for row in infobox.find_all('tr'):
            th = row.find('th')
            if th and 'Parent' in th.text:
                td = row.find('td')
                for link in td.find_all('a'):
                    href = link.get('href')
                    if href and '/wiki/' in href and 'Wikipedia:' not in href:
                        # Add the parent's URL to the list
                        parents.append(href) 
    
    # Look for parents in the "Personal life" section
    if personal_life_section is not None:
        personal_life_content = personal_life_section #.parent.find_next_sibling('div', {'class': 'hatnote'})
        #print("persona life content" + personal_life_content.text)
        if personal_life_content is not None:
            for link in personal_life_content.find_next('p').find_all('a'):
                href = link.get('href')
                #print(href)
                if href and '/wiki/' in href and 'Wikipedia:' not in href:
                    # Check if the hyperlink points to a person with the same last name
                    link_text = link.text
                    #print(link_text)
                    if last_name is None:
                        # Get the last name of the person whose page we're on
                        name = soup.find('h1', {'id': 'firstHeading'}).text
                        last_name = name.split()[-1]
                        print(last_name)
                    if last_name in link_text:
                        # Add the parent's URL to the list
                        parents.append(href)
    
    # Check if a parent has a Wikipedia page
    for parent in parents:
        parent_url = 'https://en.wikipedia.org' + parent
        parent_response = requests.get(parent_url)
        parent_soup = BeautifulSoup(parent_response.content, 'html.parser')
        parent_title = parent_soup.find('h1', {'id': 'firstHeading'}).text
        if parent_title != 'Wikipedia':
            # Check if the parent's page exists
            return True
    
    return False

# %%
#This method assumes the "players_id" and "win" are colunms in the matches_df.
#This method returns a players win ratio

def win_ratio(players_id,matches_df):
    # get dataframe of just this players matches
    this_playes_matches = matches_df[matches_df["players_id"] == players_id]
    # return win loss ratio 
    return len(this_playes_matches[this_playes_matchesm["win"] == True])/len(this_playes_matches)

# %%
#This method assumes the "players_id", "odds", and "win" are colunms in the matches_df.
#This method returns the betting multiplyer for a player. It assumes the same value if bet on each match. 
#The bet being to win the match


def betting_returns(players_id,matches_df):
    this_playes_matches = matches_df[matches_df["players_id"] == players_id]
    for index, row in this_playes_matches.iterrows():
        if this_playes_matches.at[index, 'id'] == True:
            betting_return = betting_return + this_playes_matches.at[index, 'odds']
        else:
            betting_return = betting_return - 1
            
    return betting_return

# %% [markdown]
# ### All API calls

# %%
ultimate_tennis_headers = {
	"X-RapidAPI-Key": 'dc6d9587f3mshae60004afa47d06p138d95jsn2be153d18d4a',
	"X-RapidAPI-Host": 'ultimate-tennis1.p.rapidapi.com'
}

# %% [markdown]
# #### All ATP player rankings

# %%
url = "https://ultimate-tennis1.p.rapidapi.com/rankings/atp/singles/200/current"

top_atp_response = requests.get(url, headers=ultimate_tennis_headers)
top_atp_response = pd.DataFrame(top_atp_response.json()['data'])

# %% [markdown]
# #### All WTA player rankings

# %%
url = "https://ultimate-tennis1.p.rapidapi.com/rankings/wta/singles/200/current"

top_wta_response = requests.get(url, headers=ultimate_tennis_headers)
top_wta_response = pd.DataFrame(top_wta_response.json()['data'])

# %% [markdown]
# ### read csv files
# notes on what each column means can be found in ../datasets/datasets_notes.txt
#
# data taken from [tennis-data](http://www.tennis-data.co.uk/alldata.php)

# %%
wta2019_tornament_matches = pd.read_csv('datasets/2019wta.csv')
wta2020_tornament_matches  = pd.read_csv('datasets/2020wta.csv')
wta2021_tornament_matches  = pd.read_csv('datasets/2021wta.csv')
wta2022_tornament_matches  = pd.read_csv('datasets/2022wta.csv')
wta2023_tornament_matches  = pd.read_csv('datasets/2023wta.csv')

# %%
wta_dfs = [wta2019_tornament_matches , wta2020_tornament_matches , 
           wta2021_tornament_matches , wta2022_tornament_matches , 
           wta2023_tornament_matches ]
wta_tournament_matches_wOdds = pd.concat(wta_dfs)

# %%
atp2019_tornament_matches  = pd.read_csv('datasets/2019atp.csv')
atp2020_tornament_matches  = pd.read_csv('datasets/2020atp.csv')
atp2021_tornament_matches  = pd.read_csv('datasets/2021atp.csv')
atp2022_tornament_matches  = pd.read_csv('datasets/2022atp.csv')
atp2023_tornament_matches  = pd.read_csv('datasets/2023atp.csv')

# %%
atp_dfs = [atp2019_tornament_matches , atp2020_tornament_matches , atp2021_tornament_matches , atp2022_tornament_matches , atp2023_tornament_matches ]
atp_tournament_matches_wOdds = pd.concat(atp_dfs)

# %% [markdown]
# ### DataFrame edits

# %% [markdown]
# #### Get  top 200 ATP and WTA players into a single DataFrame

# %%
# edit ATP dataframe to show basic player details

top_atp_response.set_index('id', inplace=True)

top_atp_response = top_atp_response.drop(['Rank Diff', 'Age', 'Points'], axis=1)

# %%
top_atp_response["Association"] = "ATP"

# %%
# edit WTA players dataframe to show basic player details

# drop and normalise some columns
top_wta_response = top_wta_response.drop(['country', 'movement', 'rankedAt', 'points', 'tournamentsPlayed'], axis=1)
top_wta_response.rename(columns={'ranking': 'Rank'}, inplace=True)
top_wta_response.rename(columns={'name': 'Name'}, inplace=True)

top_wta_response.set_index('ID', inplace=True)

# %%
top_players = pd.concat([top_atp_response, top_wta_response])

# %%
top_players.head()
# Out:
#                     Name  Rank Association
# a0e2      Carlos Alcaraz     1         ATP
# mm58     Daniil Medvedev     2         ATP
# d643      Novak Djokovic     3         ATP
# rh16         Casper Ruud     4         ATP
# te51  Stefanos Tsitsipas     5         ATP

# %% [markdown]
# #### edit tournaments with odds DataFrames

# %%
# join wta & atp tournament with betting odds DataFrames
all_tournament_matches_wOdds = pd.concat([wta_tournament_matches_wOdds, atp_tournament_matches_wOdds])

# %%
# create unique index for all tournamnets with odds
all_tournament_matches_wOdds['index'] = all_tournament_matches_wOdds['WTA'].astype(str) + '_' + all_tournament_matches_wOdds['ATP'].astype(str) + '_' + all_tournament_matches_wOdds['Tournament'].astype(str)
all_tournament_matches_wOdds.set_index('index', inplace=True)

# %%
all_tournament_matches_wOdds.head()
# Out:
#                      WTA  Location   Tournament        Date           Tier  \
# index
# 1.0_nan_ASB Classic  1.0  Auckland  ASB Classic  31/12/2018  International
# 1.0_nan_ASB Classic  1.0  Auckland  ASB Classic  31/12/2018  International
# 1.0_nan_ASB Classic  1.0  Auckland  ASB Classic  31/12/2018  International
# 1.0_nan_ASB Classic  1.0  Auckland  ASB Classic  31/12/2018  International
# 1.0_nan_ASB Classic  1.0  Auckland  ASB Classic  31/12/2018  International
#
#                        Court Surface      Round  Best of             Winner  \
# index
# 1.0_nan_ASB Classic  Outdoor    Hard  1st Round      3.0            Puig M.
# 1.0_nan_ASB Classic  Outdoor    Hard  1st Round      3.0           Davis L.
# 1.0_nan_ASB Classic  Outdoor    Hard  1st Round      3.0         Kuzmova V.
# 1.0_nan_ASB Classic  Outdoor    Hard  1st Round      3.0        Bouchard E.
# 1.0_nan_ASB Classic  Outdoor    Hard  1st Round      3.0  Sorribes Tormo S.
#
#                      ...  MaxW  MaxL  AvgW  AvgL  ATP  Series  W4  L4  W5  L5
# index                ...
# 1.0_nan_ASB Classic  ...  1.43  3.29  1.37  3.09  NaN     NaN NaN NaN NaN NaN
# 1.0_nan_ASB Classic  ...  1.57  2.88  1.50  2.59  NaN     NaN NaN NaN NaN NaN
# 1.0_nan_ASB Classic  ...  1.68  2.50  1.62  2.28  NaN     NaN NaN NaN NaN NaN
# 1.0_nan_ASB Classic  ...  1.66  2.75  1.53  2.51  NaN     NaN NaN NaN NaN NaN
# 1.0_nan_ASB Classic  ...  3.27  1.65  2.35  1.59  NaN     NaN NaN NaN NaN NaN
#
# [5 rows x 38 columns]

# %% [markdown]
# #### Players

# %%
# add a wealthy_parent column

players_df["wealthy_parents"] = None

# %%
#loop through all players and find if chatGPT thinks they had wealthy parents

for index, row in players_df.iterrows():
    player_name = row['Name']
    wealthy_parents = determine_wealthy_parents(player_name)
    players_df.at[index, 'wealthy_parents'] = wealthy_parents
    #print(player_name + " weathly parents is " + str(wealthy_parents))
    
players_df.head()

# %%
# add a wealthy_parent column

top_players["wealthy_parents"] = None

# %%
#loop through all players and find if chatGPT thinks they had wealthy parents

for index, row in top_players.iterrows():
    player_name = row['Name']
    wealthy_parents = determine_wealthy_parents(player_name)
    top_players.at[index, 'wealthy_parents'] = wealthy_parents
    #print(player_name + " weathly parents is " + str(wealthy_parents))
    
top_players.head()
# Out:
#                     Name  Rank Association wealthy_parents
# a0e2      Carlos Alcaraz     1         ATP           False
# mm58     Daniil Medvedev     2         ATP           False
# d643      Novak Djokovic     3         ATP            None
# rh16         Casper Ruud     4         ATP            True
# te51  Stefanos Tsitsipas     5         ATP            True

# %% [markdown]
# ## Limitations of chatGPT results
# Better tennis players will have more written about them and their families. A large language model will have more infomation about them. This may skew the results, because there may be players who are not so good at tennis, but who still have wealthy parents, but there is not enough info about them so chatGPT will say no.

# %% [markdown]
# ## How to check the ChatGPT results?
# To check how accurate they are we will querry wiki to see what players have parents with wiki pages. We can the compare to see if chat gpt say all players that have parents that have wiki pages are weatlth, then this gives us some evendence that chat GPT is telling the truth.
#
# We are only looking a general trends so we only need chatGPT to be "about right", it does not need to be 100% accurate to allow us to get some idea if wealth parents play a role.

# %%
# add a parent_on_wiki column

top_players["parent_on_wiki"] = None
top_players[['FirstName', 'LastName']] = top_players['Name'].str.split(' ', 1, expand=True)

top_players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 400 entries, a0e2 to 328578
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             400 non-null    object
#  1   Rank             400 non-null    int64
#  2   Association      200 non-null    object
#  3   wealthy_parents  392 non-null    object
#  4   parent_on_wiki   0 non-null      object
#  5   FirstName        400 non-null    object
#  6   LastName         400 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 41.2+ KB

# %%
# scrape wiki for parents hyperlinks
#this takes a longtime.

def check_wikipedia_url(url):
    response = requests.head(url)
    if response.status_code == 200:
        return True
    else:
        return False

for index, row in top_players.iterrows():
    player_name = row['FirstName'] + "_" + row['LastName']
    wiki_url = "https://en.wikipedia.org/wiki/" + player_name
    
    if check_wikipedia_url(wiki_url):
        print(wiki_url)
        wiki_parents = parents_have_wiki(wiki_url)
        print(wiki_parents)
        top_players.at[index, 'parent_on_wiki'] = wiki_parents
# Out:
# https://en.wikipedia.org/wiki/Carlos_Alcaraz
# Alcaraz
# False
# https://en.wikipedia.org/wiki/Daniil_Medvedev
# False
# https://en.wikipedia.org/wiki/Novak_Djokovic
# False
# https://en.wikipedia.org/wiki/Casper_Ruud
# Ruud
# True
# https://en.wikipedia.org/wiki/Stefanos_Tsitsipas
# Tsitsipas
# False
# https://en.wikipedia.org/wiki/Holger_Rune
# Rune
# False
# https://en.wikipedia.org/wiki/Andrey_Rublev
# Rublev
# False
# https://en.wikipedia.org/wiki/Jannik_Sinner
# Sinner
# False
# https://en.wikipedia.org/wiki/Taylor_Fritz
# False
# https://en.wikipedia.org/wiki/Felix_Auger-Aliassime
# Auger-Aliassime
# False
# https://en.wikipedia.org/wiki/Karen_Khachanov
# Khachanov
# False
# https://en.wikipedia.org/wiki/Frances_Tiafoe
# Tiafoe
# False
# https://en.wikipedia.org/wiki/Hubert_Hurkacz
# Hurkacz
# False
# https://en.wikipedia.org/wiki/Cameron_Norrie
# False
# https://en.wikipedia.org/wiki/Rafael_Nadal
# Nadal
# True
# https://en.wikipedia.org/wiki/Borna_Coric
# Ćorić
# False
# https://en.wikipedia.org/wiki/Tommy_Paul
# False
# https://en.wikipedia.org/wiki/Lorenzo_Musetti
# Musetti
# False
# https://en.wikipedia.org/wiki/Matteo_Berrettini
# Berrettini
# False
# https://en.wikipedia.org/wiki/Marin_Cilic
# Čilić
# False
# https://en.wikipedia.org/wiki/Daniel_Evans
# False
# https://en.wikipedia.org/wiki/Nick_Kyrgios
# Kyrgios
# False
# https://en.wikipedia.org/wiki/Jan-Lennard_Struff
# False
# https://en.wikipedia.org/wiki/Alexander_Zverev
# Zverev
# False
# https://en.wikipedia.org/wiki/Francisco_Cerundolo
# Cerúndolo
# True
# https://en.wikipedia.org/wiki/Sebastian_Korda
# False
# https://en.wikipedia.org/wiki/Denis_Shapovalov
# Shapovalov
# False
# https://en.wikipedia.org/wiki/Yoshihito_Nishioka
# False
# https://en.wikipedia.org/wiki/Grigor_Dimitrov
# Dimitrov
# False
# https://en.wikipedia.org/wiki/Ben_Shelton
# False
# https://en.wikipedia.org/wiki/Miomir_Kecmanovic
# False
# https://en.wikipedia.org/wiki/Ugo_Humbert
# Humbert
# False
# https://en.wikipedia.org/wiki/Tallon_Griekspoor
# Griekspoor
# True
# https://en.wikipedia.org/wiki/Jiri_Lehecka
# Lehečka
# False
# https://en.wikipedia.org/wiki/Andy_Murray
# False
# https://en.wikipedia.org/wiki/Maxime_Cressy
# False
# https://en.wikipedia.org/wiki/Emil_Ruusuvuori
# False
# https://en.wikipedia.org/wiki/Sebastian_Baez
# False
# https://en.wikipedia.org/wiki/Lorenzo_Sonego
# Sonego
# False
# https://en.wikipedia.org/wiki/Adrian_Mannarino
# False
# https://en.wikipedia.org/wiki/Alexander_Bublik
# False
# https://en.wikipedia.org/wiki/J.J._Wolf
# False
# https://en.wikipedia.org/wiki/Richard_Gasquet
# Gasquet
# False
# https://en.wikipedia.org/wiki/Dusan_Lajovic
# Lajović
# False
# https://en.wikipedia.org/wiki/Brandon_Nakashima
# Nakashima
# False
# https://en.wikipedia.org/wiki/Mikael_Ymer
# Ymer
# True
# https://en.wikipedia.org/wiki/Nicolas_Jarry
# False
# https://en.wikipedia.org/wiki/Gregoire_Barrere
# False
# https://en.wikipedia.org/wiki/Mackenzie_McDonald
# McDonald
# False
# https://en.wikipedia.org/wiki/Laslo_Djere
# False
# https://en.wikipedia.org/wiki/Yibing_Wu
# False
# https://en.wikipedia.org/wiki/Jack_Draper
# False
# https://en.wikipedia.org/wiki/Corentin_Moutet
# Moutet
# False
# https://en.wikipedia.org/wiki/Aslan_Karatsev
# Karatsev
# False
# https://en.wikipedia.org/wiki/Pedro_Cachin
# False
# https://en.wikipedia.org/wiki/Yannick_Hanfmann
# False
# https://en.wikipedia.org/wiki/Benjamin_Bonzi
# False
# https://en.wikipedia.org/wiki/Albert_Ramos-Vinolas
# Viñolas
# False
# https://en.wikipedia.org/wiki/Max_Purcell
# False
# https://en.wikipedia.org/wiki/Jason_Kubler
# Kubler
# False
# https://en.wikipedia.org/wiki/Constant_Lestienne
# False
# https://en.wikipedia.org/wiki/Zhizhen_Zhang
# Zhizhen
# False
# https://en.wikipedia.org/wiki/Jordan_Thompson
# False
# https://en.wikipedia.org/wiki/Daniel_Altmaier
# False
# https://en.wikipedia.org/wiki/Marco_Cecchinato
# False
# https://en.wikipedia.org/wiki/Marcos_Giron
# False
# https://en.wikipedia.org/wiki/Christopher_Eubanks
# False
# https://en.wikipedia.org/wiki/Nuno_Borges
# False
# https://en.wikipedia.org/wiki/Jaume_Munar
# False
# https://en.wikipedia.org/wiki/Arthur_Rinderknech
# Rinderknech
# False
# https://en.wikipedia.org/wiki/Marton_Fucsovics
# False
# https://en.wikipedia.org/wiki/Marc-Andrea_Huesler
# False
# https://en.wikipedia.org/wiki/Alexei_Popyrin
# Popyrin
# False
# https://en.wikipedia.org/wiki/Alex_Molcan
# False
# https://en.wikipedia.org/wiki/Alexander_Shevchenko
# False
# https://en.wikipedia.org/wiki/Christopher_O'Connell
# False
# https://en.wikipedia.org/wiki/Ilya_Ivashka
# Ivashka
# False
# https://en.wikipedia.org/wiki/Quentin_Halys
# False
# https://en.wikipedia.org/wiki/Stan_Wawrinka
# Wawrinka
# False
# https://en.wikipedia.org/wiki/John_Isner
# Isner
# False
# https://en.wikipedia.org/wiki/Dominic_Thiem
# Thiem
# False
# https://en.wikipedia.org/wiki/Filip_Krajinovic
# Krajinović
# False
# https://en.wikipedia.org/wiki/Diego_Schwartzman
# Schwartzman
# False
# https://en.wikipedia.org/wiki/Federico_Coria
# Coria
# True
# https://en.wikipedia.org/wiki/Aleksandar_Vukic
# Vukic
# False
# https://en.wikipedia.org/wiki/Thiago_Monteiro
# False
# https://en.wikipedia.org/wiki/Roman_Safiullin
# False
# https://en.wikipedia.org/wiki/Jenson_Brooksby
# False
# https://en.wikipedia.org/wiki/Alexandre_Muller
# False
# https://en.wikipedia.org/wiki/Soonwoo_Kwon
# Soon-woo
# False
# https://en.wikipedia.org/wiki/Dominik_Koepfer
# False
# https://en.wikipedia.org/wiki/Borna_Gojo
# False
# https://en.wikipedia.org/wiki/Matteo_Arnaldi
# False
# https://en.wikipedia.org/wiki/Cristian_Garin
# False
# https://en.wikipedia.org/wiki/Thanasi_Kokkinakis
# Kokkinakis
# False
# https://en.wikipedia.org/wiki/Hugo_Gaston
# False
# https://en.wikipedia.org/wiki/James_Duckworth
# False
# https://en.wikipedia.org/wiki/Taro_Daniel
# Daniel
# False
# https://en.wikipedia.org/wiki/Radu_Albot
# False
# https://en.wikipedia.org/wiki/Arthur_Fils
# False
# https://en.wikipedia.org/wiki/David_Goffin
# False
# https://en.wikipedia.org/wiki/Aleksandar_Kovacevic
# False
# https://en.wikipedia.org/wiki/Fabian_Marozsan
# False
# https://en.wikipedia.org/wiki/Dominic_Stricker
# False
# https://en.wikipedia.org/wiki/Emilio_Gomez
# False
# https://en.wikipedia.org/wiki/Sebastian_Ofner
# False
# https://en.wikipedia.org/wiki/Otto_Virtanen
# Virtanen
# False
# https://en.wikipedia.org/wiki/Oscar_Otte
# False
# https://en.wikipedia.org/wiki/Pavel_Kotov
# False
# https://en.wikipedia.org/wiki/Hugo_Grenier
# False
# https://en.wikipedia.org/wiki/Michael_Mmoh
# Mmoh
# True
# https://en.wikipedia.org/wiki/Facundo_Bagnis
# False
# https://en.wikipedia.org/wiki/Zsombor_Piros
# False
# https://en.wikipedia.org/wiki/Yosuke_Watanuki
# Watanuki
# False
# https://en.wikipedia.org/wiki/Tomas_Machac
# Macháč
# False
# https://en.wikipedia.org/wiki/Francesco_Passaro
# False
# https://en.wikipedia.org/wiki/Giulio_Zeppieri
# False
# https://en.wikipedia.org/wiki/Fabio_Fognini
# Fognini
# False
# https://en.wikipedia.org/wiki/Zizou_Bergs
# False
# https://en.wikipedia.org/wiki/Norbert_Gombos
# Gombos
# False
# https://en.wikipedia.org/wiki/Lukas_Klein
# False
# https://en.wikipedia.org/wiki/Jurij_Rodionov
# Rodionov
# False
# https://en.wikipedia.org/wiki/Pedro_Martinez
# Martínez
# False
# https://en.wikipedia.org/wiki/Rinky_Hijikata
# False
# https://en.wikipedia.org/wiki/Gijs_Brouwer
# False
# https://en.wikipedia.org/wiki/Denis_Kudla
# Kudla
# False
# https://en.wikipedia.org/wiki/Liam_Broady
# False
# https://en.wikipedia.org/wiki/Raul_Brancaccio
# Brancaccio
# True
# https://en.wikipedia.org/wiki/Filip_Misolic
# False
# https://en.wikipedia.org/wiki/Jozef_Kovalik
# False
# https://en.wikipedia.org/wiki/Maximilian_Marterer
# False
# https://en.wikipedia.org/wiki/Gabriel_Diallo
# False
# https://en.wikipedia.org/wiki/Timofey_Skatov
# Skatov
# False
# https://en.wikipedia.org/wiki/Andrea_Vavassori
# False
# https://en.wikipedia.org/wiki/Benoit_Paire
# False
# https://en.wikipedia.org/wiki/Luca_Nardi
# False
# https://en.wikipedia.org/wiki/Alejandro_Tabilo
# False
# https://en.wikipedia.org/wiki/Kaichi_Uchida
# False
# https://en.wikipedia.org/wiki/Elias_Ymer
# Ymer
# True
# https://en.wikipedia.org/wiki/Enzo_Couacaud
# False
# https://en.wikipedia.org/wiki/Vasek_Pospisil
# False
# https://en.wikipedia.org/wiki/Flavio_Cobolli
# False
# https://en.wikipedia.org/wiki/Hugo_Dellien
# Dellien
# True
# https://en.wikipedia.org/wiki/Geoffrey_Blancaneaux
# False
# https://en.wikipedia.org/wiki/Vit_Kopriva
# False
# https://en.wikipedia.org/wiki/Dennis_Novak
# False
# https://en.wikipedia.org/wiki/Riccardo_Bonadio
# False
# https://en.wikipedia.org/wiki/Franco_Agamenone
# False
# https://en.wikipedia.org/wiki/Mattia_Bellucci
# False
# https://en.wikipedia.org/wiki/Hamad_Medjedovic
# False
# https://en.wikipedia.org/wiki/Jelle_Sels
# False
# https://en.wikipedia.org/wiki/Kimmer_Coppejans
# False
# https://en.wikipedia.org/wiki/Zdenek_Kolar
# False
# https://en.wikipedia.org/wiki/Bu_Yunchaokete
# False
# https://en.wikipedia.org/wiki/Damir_Dzumhur
# False
# https://en.wikipedia.org/wiki/Ivan_Gakhov
# False
# https://en.wikipedia.org/wiki/Leandro_Riedi
# False
# https://en.wikipedia.org/wiki/Jan_Choinski
# Choinski
# False
# https://en.wikipedia.org/wiki/Sho_Shimabukuro
# False
# https://en.wikipedia.org/wiki/Luciano_Darderi
# False
# https://en.wikipedia.org/wiki/Brandon_Holt
# Holt
# False
# https://en.wikipedia.org/wiki/Steve_Johnson
# False
# https://en.wikipedia.org/wiki/Andrea_Pellegrino
# False
# https://en.wikipedia.org/wiki/Seong-chan_Hong
# False
# https://en.wikipedia.org/wiki/Oleksii_Krutykh
# False
# https://en.wikipedia.org/wiki/Maximilian_Neuchrist
# False
# https://en.wikipedia.org/wiki/Alexander_Ritschard
# Ritschard
# False
# https://en.wikipedia.org/wiki/Ryan_Peniston
# False
# https://en.wikipedia.org/wiki/Andrea_Collarini
# False
# https://en.wikipedia.org/wiki/Arthur_Cazaux
# False
# https://en.wikipedia.org/wiki/Marc_Polmans
# Polmans
# False
# https://en.wikipedia.org/wiki/Nicolas_Kicker
# False
# https://en.wikipedia.org/wiki/Laurent_Lokoli
# Lokoli
# True
# https://en.wikipedia.org/wiki/Harold_Mayot
# False
# https://en.wikipedia.org/wiki/Iga_Swiatek
# Świątek
# False
# https://en.wikipedia.org/wiki/Aryna_Sabalenka
# Sabalenka
# False
# https://en.wikipedia.org/wiki/Jessica_Pegula
# Pegula
# True
# https://en.wikipedia.org/wiki/Elena_Rybakina
# False
# https://en.wikipedia.org/wiki/Caroline_Garcia
# Garcia
# False
# https://en.wikipedia.org/wiki/Coco_Gauff
# Gauff
# False
# https://en.wikipedia.org/wiki/Ons_Jabeur
# Jabeur
# False
# https://en.wikipedia.org/wiki/Maria_Sakkari
# False
# https://en.wikipedia.org/wiki/Daria_Kasatkina
# Kasatkina
# False
# https://en.wikipedia.org/wiki/Petra_Kvitova
# Kvitová
# False
# https://en.wikipedia.org/wiki/Veronika_Kudermetova
# Kudermetova
# True
# https://en.wikipedia.org/wiki/Belinda_Bencic
# Bencic
# False
# https://en.wikipedia.org/wiki/Barbora_Krejcikova
# False
# https://en.wikipedia.org/wiki/Liudmila_Samsonova
# Samsonova
# False
# https://en.wikipedia.org/wiki/Karolina_Pliskova
# Plíšková
# False
# https://en.wikipedia.org/wiki/Jelena_Ostapenko
# Ostapenko
# False
# https://en.wikipedia.org/wiki/Victoria_Azarenka
# Azarenka
# False
# https://en.wikipedia.org/wiki/Qinwen_Zheng
# False
# https://en.wikipedia.org/wiki/Madison_Keys
# Keys
# False
# https://en.wikipedia.org/wiki/Magda_Linette
# Linette
# False
# https://en.wikipedia.org/wiki/Donna_Vekic
# False
# https://en.wikipedia.org/wiki/Ekaterina_Alexandrova
# Alexandrova
# False
# https://en.wikipedia.org/wiki/Anastasia_Potapova
# False
# https://en.wikipedia.org/wiki/Anhelina_Kalinina
# False
# https://en.wikipedia.org/wiki/Martina_Trevisan
# Trevisan
# True
# https://en.wikipedia.org/wiki/Irina-Camelia_Begu
# False
# https://en.wikipedia.org/wiki/Elise_Mertens
# Mertens
# False
# https://en.wikipedia.org/wiki/Paula_Badosa
# Badosa
# False
# https://en.wikipedia.org/wiki/Shuai_Zhang
# False
# https://en.wikipedia.org/wiki/Sorana_Cirstea
# False
# https://en.wikipedia.org/wiki/Marie_Bouzkova
# False
# https://en.wikipedia.org/wiki/Shelby_Rogers
# Rogers
# False
# https://en.wikipedia.org/wiki/Simona_Halep
# Halep
# False
# https://en.wikipedia.org/wiki/Sloane_Stephens
# Stephens
# False
# https://en.wikipedia.org/wiki/Camila_Giorgi
# Giorgi
# False
# https://en.wikipedia.org/wiki/Petra_Martic
# False
# https://en.wikipedia.org/wiki/Bernarda_Pera
# Pera
# False
# https://en.wikipedia.org/wiki/Marta_Kostyuk
# False
# https://en.wikipedia.org/wiki/Lin_Zhu
# False
# https://en.wikipedia.org/wiki/Bianca_Andreescu
# Andreescu
# False
# https://en.wikipedia.org/wiki/Karolina_Muchova
# False
# https://en.wikipedia.org/wiki/Elisabetta_Cocciaretto
# False
# https://en.wikipedia.org/wiki/Varvara_Gracheva
# False
# https://en.wikipedia.org/wiki/Danielle_Collins
# Collins
# False
# https://en.wikipedia.org/wiki/Ajla_Tomljanovic
# Tomljanović
# False
# https://en.wikipedia.org/wiki/Katerina_Siniakova
# False
# https://en.wikipedia.org/wiki/Linda_Noskova
# Nosková
# False
# https://en.wikipedia.org/wiki/Alycia_Parks
# False
# https://en.wikipedia.org/wiki/Aliaksandra_Sasnovich
# False
# https://en.wikipedia.org/wiki/Leylah_Fernandez
# Fernandez
# False
# https://en.wikipedia.org/wiki/Jasmine_Paolini
# Paolini
# False
# https://en.wikipedia.org/wiki/Anna_Kalinskaya
# False
# https://en.wikipedia.org/wiki/Mayar_Sherif
# False
# https://en.wikipedia.org/wiki/Linda_Fruhvirtova
# False
# https://en.wikipedia.org/wiki/Marketa_Vondrousova
# False
# https://en.wikipedia.org/wiki/Lauren_Davis
# Davis
# True
# https://en.wikipedia.org/wiki/Alizé_Cornet
# False
# https://en.wikipedia.org/wiki/Ana_Bogdan
# Bogdan
# False
# https://en.wikipedia.org/wiki/Yulia_Putintseva
# Putintseva
# False
# https://en.wikipedia.org/wiki/Xiyu_Wang
# False
# https://en.wikipedia.org/wiki/Lesia_Tsurenko
# False
# https://en.wikipedia.org/wiki/Tatjana_Maria
# Maria
# False
# https://en.wikipedia.org/wiki/Danka_Kovinic
# False
# https://en.wikipedia.org/wiki/Anna_Blinkova
# False
# https://en.wikipedia.org/wiki/Cristina_Bucsa
# False
# https://en.wikipedia.org/wiki/Rebeka_Masarova
# Masarova
# False
# https://en.wikipedia.org/wiki/Peyton_Stearns
# False
# https://en.wikipedia.org/wiki/Sara_Errani
# False
# https://en.wikipedia.org/wiki/Viktoriya_Tomova
# False
# https://en.wikipedia.org/wiki/Jule_Niemeier
# False
# https://en.wikipedia.org/wiki/Anett_Kontaveit
# Kontaveit
# False
# https://en.wikipedia.org/wiki/Julia_Grabher
# False
# https://en.wikipedia.org/wiki/Jil_Teichmann
# False
# https://en.wikipedia.org/wiki/Kaia_Kanepi
# False
# https://en.wikipedia.org/wiki/Diane_Parry
# False
# https://en.wikipedia.org/wiki/Xinyu_Wang
# Xinyu
# False
# https://en.wikipedia.org/wiki/Rebecca_Marino
# Marino
# False
# https://en.wikipedia.org/wiki/Kateryna_Baindl
# False
# https://en.wikipedia.org/wiki/Ysaline_Bonaventure
# False
# https://en.wikipedia.org/wiki/Emma_Navarro
# Navarro
# True
# https://en.wikipedia.org/wiki/Alison_Riske-Amritraj
# Riske-Amritraj
# False
# https://en.wikipedia.org/wiki/Camila_Osorio
# Osorio
# False
# https://en.wikipedia.org/wiki/Kamilla_Rakhimova
# False
# https://en.wikipedia.org/wiki/Rebecca_Peterson
# False
# https://en.wikipedia.org/wiki/Magdalena_Frech
# False
# https://en.wikipedia.org/wiki/Maryna_Zanevska
# Zanevska
# False
# https://en.wikipedia.org/wiki/Amanda_Anisimova
# Anisimova
# False
# https://en.wikipedia.org/wiki/Katie_Volynets
# Volynets
# False
# https://en.wikipedia.org/wiki/Tereza_Martincova
# False
# https://en.wikipedia.org/wiki/Anna-Lena_Friedsam
# False
# https://en.wikipedia.org/wiki/Madison_Brengle
# Brengle
# False
# https://en.wikipedia.org/wiki/Panna_Udvardy
# False
# https://en.wikipedia.org/wiki/Dalma_Galfi
# False
# https://en.wikipedia.org/wiki/Caroline_Dolehide
# False
# https://en.wikipedia.org/wiki/Claire_Liu
# Liu
# False
# https://en.wikipedia.org/wiki/Nadia_Podoroska
# Podoroska
# False
# https://en.wikipedia.org/wiki/Lucia_Bronzetti
# False
# https://en.wikipedia.org/wiki/Anna_Bondar
# False
# https://en.wikipedia.org/wiki/Olga_Danilovic
# Danilović
# True
# https://en.wikipedia.org/wiki/Lucrezia_Stefanini
# False
# https://en.wikipedia.org/wiki/Emma_Raducanu
# False
# https://en.wikipedia.org/wiki/Diana_Shnaider
# False
# https://en.wikipedia.org/wiki/Taylor_Townsend
# False
# https://en.wikipedia.org/wiki/Jodie_Burrage
# Burrage
# False
# https://en.wikipedia.org/wiki/Tamara_Zidansek
# False
# https://en.wikipedia.org/wiki/Kimberly_Birrell
# Birrell
# False
# https://en.wikipedia.org/wiki/Nao_Hibino
# False
# https://en.wikipedia.org/wiki/Arantxa_Rus
# False
# https://en.wikipedia.org/wiki/Laura_Siegemund
# False
# https://en.wikipedia.org/wiki/Yue_Yuan
# False
# https://en.wikipedia.org/wiki/Tamara_Korpatsch
# False
# https://en.wikipedia.org/wiki/Elizabeth_Mandlik
# Mandlik
# False
# https://en.wikipedia.org/wiki/Greet_Minnen
# Minnen
# False
# https://en.wikipedia.org/wiki/Sofia_Kenin
# False
# https://en.wikipedia.org/wiki/Oceane_Dodin
# Dodin
# False
# https://en.wikipedia.org/wiki/Clara_Burel
# False
# https://en.wikipedia.org/wiki/Jessika_Ponchet
# False
# https://en.wikipedia.org/wiki/Katie_Boulter
# False
# https://en.wikipedia.org/wiki/Viktorija_Golubic
# False
# https://en.wikipedia.org/wiki/Clara_Tauson
# Tauson
# True
# https://en.wikipedia.org/wiki/Simona_Waltert
# False
# https://en.wikipedia.org/wiki/Leolia_Jeanjean
# False
# https://en.wikipedia.org/wiki/Aliona_Bolsova
# Bolsova
# False
# https://en.wikipedia.org/wiki/Aleksandra_Krunic
# False
# https://en.wikipedia.org/wiki/Elina_Avanesyan
# Avanesyan
# False
# https://en.wikipedia.org/wiki/Harriet_Dart
# Dart
# False
# https://en.wikipedia.org/wiki/Viktoria_Hruncakova
# Hrunčáková
# False
# https://en.wikipedia.org/wiki/Daria_Saville
# Saville
# True
# https://en.wikipedia.org/wiki/Kayla_Day
# False
# https://en.wikipedia.org/wiki/Laura_Pigossi
# False
# https://en.wikipedia.org/wiki/Yanina_Wickmayer
# Wickmayer
# False
# https://en.wikipedia.org/wiki/Katherine_Sebov
# Sebov
# False
# https://en.wikipedia.org/wiki/Polina_Kudermetova
# Kudermetova
# True
# https://en.wikipedia.org/wiki/Mirra_Andreeva
# Andreeva
# True
# https://en.wikipedia.org/wiki/Dayana_Yastremska
# Yastremska
# False
# https://en.wikipedia.org/wiki/Moyuka_Uchijima
# False
# https://en.wikipedia.org/wiki/Brenda_Fruhvirtova
# False
# https://en.wikipedia.org/wiki/Erika_Andreeva
# Andreeva
# True
# https://en.wikipedia.org/wiki/Ylena_In-Albon
# False
# https://en.wikipedia.org/wiki/Maria_Carle
# False
# https://en.wikipedia.org/wiki/Jaimee_Fourlis
# False
# https://en.wikipedia.org/wiki/Sinja_Kraus
# False
# https://en.wikipedia.org/wiki/Priscilla_Hon
# False
# https://en.wikipedia.org/wiki/Olivia_Gadecki
# Gadecki
# False
# https://en.wikipedia.org/wiki/Eva_Lys
# False
# https://en.wikipedia.org/wiki/Elena-Gabriela_Ruse
# False
# https://en.wikipedia.org/wiki/Despina_Papamichail
# False
# https://en.wikipedia.org/wiki/Tara_Wurth
# False
# https://en.wikipedia.org/wiki/Mirjam_Bjorklund
# Björklund
# False
# https://en.wikipedia.org/wiki/Katie_Swan
# Swan
# False
# https://en.wikipedia.org/wiki/Ashlyn_Krueger
# False
# https://en.wikipedia.org/wiki/Daria_Snigur
# False
# https://en.wikipedia.org/wiki/Coco_Vandeweghe
# Vandeweghe
# True
# https://en.wikipedia.org/wiki/Kristina_Mladenovic
# Mladenovic
# False
# https://en.wikipedia.org/wiki/Robin_Montgomery
# False
# https://en.wikipedia.org/wiki/Garbiñe_Muguruza
# Muguruza
# False
# https://en.wikipedia.org/wiki/Himeno_Sakatsume
# False
# https://en.wikipedia.org/wiki/Sachia_Vickery
# False
# https://en.wikipedia.org/wiki/Na-Lae_Han
# False
# https://en.wikipedia.org/wiki/Oksana_Selekhmeteva
# False
# https://en.wikipedia.org/wiki/Ana_Konjuh
# False
# https://en.wikipedia.org/wiki/Nuria_Brancaccio
# Brancaccio
# True
# https://en.wikipedia.org/wiki/Elsa_Jacquemot
# False
# https://en.wikipedia.org/wiki/Nigina_Abduraimova
# False
# https://en.wikipedia.org/wiki/Carol_Zhao
# Zhao
# False
# https://en.wikipedia.org/wiki/Heather_Watson
# Watson
# False
# https://en.wikipedia.org/wiki/Anastasia_Zakharova
# False
# https://en.wikipedia.org/wiki/Sara_Bejlek
# Bejlek
# False
# https://en.wikipedia.org/wiki/Chloe_Paquet
# False
# https://en.wikipedia.org/wiki/Emina_Bektas
# Bektas
# False
# https://en.wikipedia.org/wiki/Paula_Ormaechea
# Ormaechea
# False
# https://en.wikipedia.org/wiki/Marcela_Zacarias
# Zacarías
# False
# https://en.wikipedia.org/wiki/Valentini_Grammatikopoulou
# False
# https://en.wikipedia.org/wiki/Ann_Li
# Li
# False
# https://en.wikipedia.org/wiki/Selena_Janicijevic
# False
# https://en.wikipedia.org/wiki/Mai_Hontama
# False
# https://en.wikipedia.org/wiki/Alice_Robbe
# False
# https://en.wikipedia.org/wiki/Irina_Bara
# False
# https://en.wikipedia.org/wiki/Katrina_Scott
# False
# https://en.wikipedia.org/wiki/Magali_Kempen
# False
# https://en.wikipedia.org/wiki/Julia_Riera
# False
# https://en.wikipedia.org/wiki/Carole_Monnet
# Monnet
# False
# https://en.wikipedia.org/wiki/Fernanda_Contreras
# Gómez
# False
# https://en.wikipedia.org/wiki/Darja_Semenistaja
# False
# https://en.wikipedia.org/wiki/Darya_Astakhova
# False

# %%
top_players.to_csv("players.csv")

# %% [markdown]
# ## Interesting things to note about the wiki parents method.
#  It also picks up syblings that are famous (example Elias_Ymer, who had a tennis playing sybbling), and other family members (example Raffa's uncle who is famous for being Raffa's coach).
# It also sometimes picks up the wiki page of someone who shares the same name as the tennis player. Example Alexander Zhurbin https://en.wikipedia.org/wiki/Alexander_Zhurbin the musician vs the tennis player https://en.wikipedia.org/wiki/Alexander_Zhurbin_(tennis)

# %% [markdown]
# ## Checking chatGPT
# results

# %%
#Check if all players with wiki_parents are considered to have wealthy parents by chatGPT.

#this returns all rows where a player has wiki parents but they are not wealthy


all_wiki_parents = top_players[top_players['parent_on_wiki']==True]

test_wiki_vs_chatGPT = all_wiki_parents[all_wiki_parents['wealthy_parents']==False]

# %%
#Lets see what percentage the above false hits were compared to all players with wiki_parents
all_wiki_parents = top_players[top_players['parent_on_wiki']==True]
false_hit_ratio = len(test_wiki_vs_chatGPT)/len(all_wiki_parents)
print("the ratio of players with parents that have wiki pages that chat gpt does vs does not think are wealthy are: " + str(false_hit_ratio))

#Todo// Make a info graphic about this
# Out:
# the ratio of players with parents that have wiki pages that chat gpt does vs does not think are wealthy are: 0.7916666666666666

# %% [markdown]
# 80% of players that our function says have parents who have wiki pages, are not considered wealthy by chat-gpt. This not not a good test!

# %% [markdown]
# ## Results of checking wealth via chatGPT vs wiki parents
#
# The above shows that the two methods of telling if a parent is wealthy do not align. 80% of players that our function says have parents who have wiki pages, are not considered wealthy by chat-gpt. This not not a good test!
#
# There are not a huge amount of rows in either disputed list so by manually checking 5 of them from each list it seems the chat GPT results are more accurate. It seems the main problem with the wiki results is that it more often pulls up other family members other than the parents.
#
# due to this desk top evaluation we will use the chatGPT results for the rest of the analysis, noting that they have not been well checked.

# %% [markdown]
# ## Are tennis players more likely to have wealth parents that the general population:
#
# Find % of players with weathy parent.
# Compare this to general population. We said to chat GPT to use weathy as to 1%, so lets see how this compares to our sample of players.

# %%
percentage_wealthy = players_df['wealthy_parents'].mean() * 100
percentage_wealthy
# Out:
# 4.804974561899378

# %% [markdown]
# 5% > 1% so this sugests that tennis players are more often from wealthy families.

# %% [markdown]
# #### Merge all DataFrames into one

# %%
# get first initial from players_df players to check against tornament details
test_chatGPT_vs_wiki['first_initial'] = test_chatGPT_vs_wiki['first_name'].str[0]

all_tournament_matches_wOdds[['last_name','first_initial']] = all_tournament_matches_wOdds['Winner'].str.split(' ', n=1, expand=True)
all_tournament_matches_wOdds['first_initial'] = all_tournament_matches_wOdds['first_initial'].str.extract(r'(\w)')

# %%
# join player_df and tournament odds dataframes into one
player_odds_df = test_chatGPT_vs_wiki.merge(all_tournament_matches_wOdds, on=['first_initial', 'last_name'])
player_odds_df = player_odds_df.drop(['full_name', 'first_initial', 'Winner'], axis=1)

# remove the one tournament without odds
player_odds_df.drop(index=455, inplace=True)

# create csv with all players and odds
player_odds_df.to_csv('all players tournaments odds.csv')

# %% [markdown]
# ## Do players with wealthy parents have a better win ratio?
# ### Popuate players_df with win_ratio

# %%
#this assumes that the df that contains all the matches split so one row one player is called "all_tournament_matches_wOdds_split"

top_players["win_ratio"] = None
for index, row in top_players.iterrows():
    top_players.at[index, 'win_ratio'] = win_ratio(top_players.at[index, 'id'], all_tournament_matches_wOdds_split)

# %% [markdown]
# ### Find out if the average win_ratio is higer if the parents are wealthy

# %%
wealthy_parents_players_df = top_players[top_players[wealthy_parents] == True]
average_win_ratio_wealthy_parents = wealthy_parents_players_df["win_ratio"].mean()
print("Players with wealth parents have a win ratio of " + str(average_win_ratio_wealthy_parents))

not_wealth_parents_players_df = top_players[top_players[wealthy_parents] == False]
average_win_ratio_not_wealthy_parents = not_wealth_parents_players_df["win_ratio"].mean()
print("Players who do not have wealth parents have a win ratio of " + str(average_win_ratio_not_wealthy_parents))

# %% [markdown]
# ## What returns would you make if you bet on players who had wealthy parents?
#
# To answer this lets loop though all players with wealthy parents (acording the chatGPT) and see if we bet the same amount on all there matches over the last 4 years, if we would have made a profit.

# %%
# this loops through all players and calulates the return if you had bet 1$ on each of there matches over the last 4 years.
top_players["bet_return"] = None
for index, row in top_players.iterrows():
    top_players.at[index, 'bet_return'] = betting_returns(top_players.at[index, 'id'], all_tournament_matches_wOdds_split)

# %%
wealthy_parents_players_df = top_players[top_players[wealthy_parents] == True]
average_betting_return_wealthy_parents = wealthy_parents_players_df["bet_return"].mean()
print("Players with wealth parents have an average betting return of" + str(average_betting_return_wealthy_parents))

not_wealth_parents_players_df = top_players[top_players[wealthy_parents] == False]
average_betting_return_not_wealthy_parents = not_wealth_parents_players_df["bet_return"].mean()
print("Players who do not have wealth parents have an average betting return of " + str(average_betting_return_not_wealthy_parents))
